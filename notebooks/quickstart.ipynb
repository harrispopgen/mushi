# %% [markdown]
# Quickstart
# ==
#
# This page demonstrates how to use the Python module `mushi` to infer demographic history and mutation spectrum history

# %% [markdown]
# We use `mushi` to infer effective population size history and history of the mutation process, which we can think of as the mutation rate function over time for each of many mutation types.
# In `mushi`, we use coalescent theory and optimization techniques to learn about this history from the $k$-SFS: a matrix whose columns are sample frequency spectra (SFS) for each mutation type (or just the standard SFS if we are only interested in inferring demographic history).
#
#
# ## Imports
# We first import the `mushi` package, and a few other standard packages.

# %%
import mushi

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading sample frequency spectrum data
#
# The most important class in the `mushi` package is the `kSFS`, which holds site frequency spectrum (SFS) data, or $k$-SFS data for multiple mutation types.
# There are several ways to instantiate a `kSFS` object (for details read the API documentation):
#
# ### 1. From a `numpy` array
#
# Here we demonstrate a `kSFS` instantiated from a numpy array, and then a plot of the resulting SFS.

# %%
x = 1e6 / np.arange(1, 200)

ksfs = mushi.kSFS(X=x)

ksfs.plot_total()
plt.xscale('log')
plt.yscale('log')

# %% [markdown]
# ### 2. From a tsv file
#
# For example, suppose a file `ksfs.tsv` contains $k$-SFS data (in the format generated by the seperate `mutyper` package), or simply an SFS with sample frequencies in the first column and variant counts in the second. The `kSFS` is instantiated as
#
# ```python
# ksfs = mushi.kSFS(file='ksfs.tsv')
# ```
#
# ### 3. By simulation
#
# We can also instantiate by only specifying the number of number of sampled haplotypes $n$, then generating simulated SFS or $k$-SFS data by specifying a demographic history and a optionally a mutation spectrum history.
# We will proceed with this approach for this demonstration.

# %%
ksfs = mushi.kSFS(n=200)

# %% [markdown]
# We now define a true demographic history for simulation (note that for inference on real data, this is not necessary).
# In `mushi`, the demographic history is denoted by the haploid effective population size history $\eta(t)$ ("eta" of t), and can be constructed using the class `mushi.eta`.
#
# **Note that for diploids, $\eta(t)=2N(t)$.**
#
# We instantiate demographic history with a vector of times (into the past) when the population size changes, and a vector of population sizes in each interval.
# Here we define a simple bottleneck history, and plot it.

# %%
t = np.logspace(0, 4, 100)
y = 1e4 * np.ones(t.size + 1)
y[40:60] /= 4

eta_true = mushi.eta(t, y)

eta_true.plot()

# %% [markdown]
# Now we simulate SFS data using this demographic history.
# We also specify a constant mutation rate (mutations per genome per generation), a rate of ancestral misidentification, and a random seed.

# %%
mu0 = 50
ksfs.simulate(eta_true, mu0, r=0.02, seed=1)

ksfs.plot_total()
plt.xscale('log')
plt.yscale('log')

# %% [markdown]
# ## Demographic inference
#
# With SFS data defined, we can attempt to infer demographic history, and ask if it resembles the true history we used to simulate the data.
#
# Demographic inference requires an estimate of the total mutation rate, and optional regularization penalties.
#
# ### Regularization parameters
#
# - The most important regularization parameter is the trend penalty, a tuple `(k, λ)`. This indicates a trend penalty of order `k` and strength `λ`. Inference will favor piece-wise polynomial solutions, with pieces of order `k`. For example using a 0th order penalty (as we do below) will favor piece-wise constant solutions. Using a 1st order penalty would allow linear pieces, and a 2nd order penalty would allow quadratic pieces, etc. Multiple trend penalty tuples can be supplied, which will result in solutions that are a mix of pieces of different orders.
# - An additional `ridge_penalty` parameter improves convergence without noticably affecting the solution, so we recommend using a small one, typically `1e-4`.
#
# We use a single 0th order trend penalty, to favor piecewise constant solutions. The choice of which trend orders to use is a model selection choice that should be judiciously chosen, possible based on domain knowledge about the population under study.
#
# We also can specify the number of iterations (if we want more than the default), and a verbosity level to print info about progress.

# %%
ksfs.infer_eta(mu0,
               (0, 1e2),  # <-- trend penalty
               ridge_penalty = 1e-4,
               max_iter=300,
               verbose=True)
# Out:
# initial objective -4.258435e+07
# iteration 1, objective -4.275e+07, relative change 3.780e-03
# iteration 2, objective -4.276e+07, relative change 4.122e-04
# iteration 3, objective -4.277e+07, relative change 1.578e-04
# iteration 4, objective -4.277e+07, relative change 1.010e-04
# iteration 5, objective -4.278e+07, relative change 6.811e-05
# iteration 6, objective -4.278e+07, relative change 4.747e-05
# iteration 7, objective -4.278e+07, relative change 3.263e-05
# iteration 8, objective -4.278e+07, relative change 2.182e-05
# iteration 9, objective -4.278e+07, relative change 1.415e-05
# iteration 10, objective -4.278e+07, relative change 9.001e-06
# iteration 11, objective -4.278e+07, relative change 5.868e-06
# iteration 12, objective -4.278e+07, relative change 4.322e-06
# iteration 13, objective -4.278e+07, relative change 3.765e-06
# iteration 14, objective -4.278e+07, relative change 3.812e-06
# iteration 15, objective -4.278e+07, relative change 3.956e-06
# iteration 16, objective -4.278e+07, relative change 4.002e-06
# iteration 17, objective -4.278e+07, relative change 3.872e-06
# iteration 18, objective -4.278e+07, relative change 3.614e-06
# iteration 19, objective -4.278e+07, relative change 3.261e-06
# iteration 20, objective -4.278e+07, relative change 2.892e-06
# iteration 21, objective -4.278e+07, relative change 2.552e-06
# iteration 22, objective -4.278e+07, relative change 2.223e-06
# iteration 23, objective -4.278e+07, relative change 1.919e-06
# iteration 24, objective -4.278e+07, relative change 1.687e-06
# iteration 25, objective -4.278e+07, relative change 1.483e-06
# iteration 26, objective -4.278e+07, relative change 1.290e-06
# iteration 27, objective -4.278e+07, relative change 1.115e-06
# iteration 28, objective -4.278e+07, relative change 9.379e-07
# iteration 29, objective -4.278e+07, relative change 7.944e-07
# iteration 30, objective -4.278e+07, relative change 6.479e-07
# iteration 31, objective -4.278e+07, relative change 5.339e-07
# iteration 32, objective -4.278e+07, relative change 4.451e-07
# iteration 33, objective -4.278e+07, relative change 3.656e-07
# iteration 34, objective -4.278e+07, relative change 2.922e-07
# iteration 35, objective -4.278e+07, relative change 2.215e-07
# iteration 36, objective -4.278e+07, relative change 1.836e-07
# iteration 37, objective -4.278e+07, relative change 1.419e-07
# iteration 38, objective -4.278e+07, relative change 1.198e-07
# iteration 39, objective -4.278e+07, relative change 1.413e-07
# iteration 40, objective -4.278e+07, relative change 1.413e-07
# iteration 41, objective -4.278e+07, relative change 1.329e-07
# iteration 42, objective -4.278e+07, relative change 1.654e-07
# iteration 43, objective -4.278e+07, relative change 1.767e-07
# iteration 44, objective -4.278e+07, relative change 1.730e-07
# iteration 45, objective -4.278e+07, relative change 1.432e-07
# iteration 46, objective -4.278e+07, relative change 1.642e-07
# iteration 47, objective -4.278e+07, relative change 1.727e-07
# iteration 48, objective -4.278e+07, relative change 1.736e-07
# iteration 272, objective -4.278e+07, relative change 1.241e-08
# iteration 273, objective -4.278e+07, relative change 8.302e-09
# iteration 274, objective -4.278e+07, relative change 7.990e-09
# iteration 275, objective -4.278e+07, relative change 7.270e-09
# iteration 276, objective -4.278e+07, relative change 2.386e-09
# iteration 277, objective -4.278e+07, relative change 2.982e-09
# iteration 278, objective -4.278e+07, relative change 3.029e-09
# iteration 279, objective -4.278e+07, relative change 3.004e-09
# iteration 280, objective -4.278e+07, relative change 3.011e-09
# iteration 281, objective -4.278e+07, relative change 3.102e-09
# iteration 282, objective -4.278e+07, relative change 2.543e-09
# iteration 283, objective -4.278e+07, relative change 2.295e-09
# iteration 284, objective -4.278e+07, relative change 2.410e-09
# iteration 285, objective -4.278e+07, relative change 2.746e-09
# iteration 286, objective -4.278e+07, relative change 3.095e-09
# iteration 287, objective -4.278e+07, relative change 3.229e-09
# iteration 288, objective -4.278e+07, relative change 2.929e-09
# iteration 289, objective -4.278e+07, relative change 3.150e-09
# iteration 290, objective -4.278e+07, relative change 2.960e-09
# iteration 291, objective -4.278e+07, relative change 3.024e-09
# iteration 292, objective -4.278e+07, relative change 3.619e-09
# iteration 293, objective -4.278e+07, relative change 4.317e-09
# iteration 294, objective -4.278e+07, relative change 3.248e-09
# iteration 295, objective -4.278e+07, relative change 2.282e-09
# iteration 296, objective -4.278e+07, relative change 1.530e-09
# iteration 297, objective -4.278e+07, relative change 1.058e-09
# iteration 298, objective -4.278e+07, relative change 6.960e-10
# iteration 299, objective -4.278e+07, relative change 1.077e-09
# iteration 300, objective -4.278e+07, relative change 3.459e-09
# maximum iteration 300 reached with relative change in objective function 3.5e-09

# %% [markdown]
# We can now plot the fit to the SFS, as well as the inferred history alongside the true history. The inferred history is contained in the attribute `eta` of the `kSFS` object.

# %%
plt.subplot(121)
ksfs.plot_total()
plt.xscale('log')
plt.yscale('log')

plt.subplot(122)
eta_true.plot(label='true')
ksfs.eta.plot(label='inferred')
plt.legend();

# %% [markdown]
# The ancestral misidentification rate was also inferred (to fit the "smile"), and we can check that it is near the true value used to simulate.

# %%
ksfs.r
# Out:
# Array(0.02017785, dtype=float64)

# %% [markdown]
# ### Folded SFS
#
# For non-model organisms, it is often difficult to polarize the ancestral state of SNPs.
# The SFS can be supplied with reference polarized data, and inference can be performed using the flag `folded=True`, to use the folded SFS (aggregating each sample frequence with its complement).
# We can repeate the above inference using folded SFS inference to get similar results.

# %%
ksfs.infer_eta(mu0,
               (0, 1e2),
               ridge_penalty = 1e-4,
               folded=True,
               max_iter=300, verbose=True)

plt.subplot(121)
ksfs.plot_total(folded=True)
plt.xscale('log')
plt.yscale('log')

plt.subplot(122)
eta_true.plot(label='true')
ksfs.eta.plot(label='inferred')
plt.legend();
# Out:
# initial objective -4.451610e+07
# iteration 1, objective -4.452e+07, relative change 5.285e-10
# iteration 2, objective -4.452e+07, relative change 1.791e-14
# iteration 3, objective -4.452e+07, relative change 2.595e-10
# iteration 4, objective -4.452e+07, relative change 2.678e-14
# iteration 5, objective -4.452e+07, relative change 3.147e-14
# iteration 6, objective -4.452e+07, relative change 3.565e-14
# iteration 285, objective -4.452e+07, relative change 2.265e-12
# iteration 286, objective -4.452e+07, relative change 2.278e-12
# iteration 287, objective -4.452e+07, relative change 2.289e-12
# iteration 288, objective -4.452e+07, relative change 2.302e-12
# iteration 289, objective -4.452e+07, relative change 2.313e-12
# iteration 290, objective -4.452e+07, relative change 2.325e-12
# iteration 291, objective -4.452e+07, relative change 2.338e-12
# iteration 292, objective -4.452e+07, relative change 2.349e-12
# iteration 293, objective -4.452e+07, relative change 2.361e-12
# iteration 294, objective -4.452e+07, relative change 2.374e-12
# iteration 295, objective -4.452e+07, relative change 2.385e-12
# iteration 296, objective -4.452e+07, relative change 2.398e-12
# iteration 297, objective -4.452e+07, relative change 2.410e-12
# iteration 298, objective -4.452e+07, relative change 2.422e-12
# iteration 299, objective -4.452e+07, relative change 2.434e-12
# iteration 300, objective -4.452e+07, relative change 2.446e-12
# maximum iteration 300 reached with relative change in objective function 2.4e-12

# %% [markdown]
# ## Mutation spectrum history (mush) inference
#
# We now consider data that is resolved into different mutation types (e.g. 96 triplet mutation types), and we have an SFS for each type as a separate column of a $k$-SFS matrix.
# As described above, a `kSFS` can be instantiated from a numpy array, or loaded from a tsv file.
# Here we'll again simulate one, so we first need to define a true mutation spectrum history.
#
# In `mushi`, the mush is denoted by a time dependent mutation rate history vector $\boldsymbol\mu(t)$ ("mu" of t), and can be constructed using the class `mushi.mu`.
# Each component of the vector is the mutation rate for one mutation type (e.g. one triplet type, like `AAA>ACA`).
#
# We instantiate mush with a vector of times (into the past) when the mush changes, and a _matrix_ of mutation rate vectors in each interval.
# Here we define a a 96 dimensional history where all are constant in time except two: a pulse and a monotonic ramp.
# Here again, note that this step would not be necessary for inference on real data, but is needed for this demonstration.
#
# To simplify things, we'll aggregate all the constant mutation types, so we have mutation types: `TCC>TTC`, `GAA>GGA`, and `None` (which will contain the remaining 94 mutation types.

# %%
Z = np.ones((t.size + 1, 3))

# pulse
Z[40:70, 0] *= 2
Z[:40, 0] *= 1.2
Z[:, 0] *= 2

# ramp
Z[25:75, 1] *= np.linspace(2, 1, 50)
Z[:25, 1] *= 2

# flat
Z[:, 2] *= 94

# We model a TCC>TTC, it's revertant type GAA>GGA (for ancestral misidentification),
# and aggregate category for the remainder of mutations
mutation_types = ['TCC>TTC', 'GAA>GGA', None]

mu_true = mushi.mu(t, Z, mutation_types)

mu_true.plot(('TCC>TTC', 'GAA>GGA'), alpha=0.75, lw=3)

# %% [markdown]
# Now simulate new $k$-SFS data assuming this mush, and plot just the first two (non-constant) components.
#
# Using the flag `clr=True` when plotting the $k$-SFS shows relative mutation counts (using a compositional transform) at each time, so it makes it easier to visualize.

# %%
ksfs = mushi.kSFS(n=200)
ksfs.simulate(eta_true, mu_true, r=0.02, seed=1)

plt.subplot(121)
ksfs.plot_total()
plt.xscale('log')
plt.yscale('log')

plt.subplot(122)
ksfs.plot(('TCC>TTC', 'GAA>GGA'), clr=True)

# %%
mu0 = Z[0, :].sum()

ksfs.infer_eta(mu0,
               (0, 1e2),
               ridge_penalty = 1e-4,
               max_iter=300, verbose=True)

plt.subplot(121)
ksfs.plot_total()
plt.xscale('log')
plt.yscale('log')

plt.subplot(122)
eta_true.plot(label='true')
ksfs.eta.plot(label='inferred')
plt.legend();
# Out:
# initial objective -8.889828e+07
# iteration 1, objective -8.920e+07, relative change 3.397e-03
# iteration 2, objective -8.923e+07, relative change 3.696e-04
# iteration 3, objective -8.925e+07, relative change 1.421e-04
# iteration 4, objective -8.925e+07, relative change 9.085e-05
# iteration 5, objective -8.926e+07, relative change 6.129e-05
# iteration 6, objective -8.926e+07, relative change 4.270e-05
# iteration 7, objective -8.927e+07, relative change 2.933e-05
# iteration 8, objective -8.927e+07, relative change 1.959e-05
# iteration 9, objective -8.927e+07, relative change 1.273e-05
# iteration 10, objective -8.927e+07, relative change 8.130e-06
# iteration 11, objective -8.927e+07, relative change 5.361e-06
# iteration 12, objective -8.927e+07, relative change 4.016e-06
# iteration 13, objective -8.927e+07, relative change 3.618e-06
# iteration 14, objective -8.927e+07, relative change 3.655e-06
# iteration 15, objective -8.927e+07, relative change 3.796e-06
# iteration 16, objective -8.927e+07, relative change 3.832e-06
# iteration 17, objective -8.927e+07, relative change 3.710e-06
# iteration 18, objective -8.927e+07, relative change 3.460e-06
# iteration 19, objective -8.927e+07, relative change 3.141e-06
# iteration 20, objective -8.927e+07, relative change 2.791e-06
# iteration 21, objective -8.927e+07, relative change 2.457e-06
# iteration 22, objective -8.927e+07, relative change 2.157e-06
# iteration 23, objective -8.927e+07, relative change 1.886e-06
# iteration 24, objective -8.927e+07, relative change 1.648e-06
# iteration 25, objective -8.927e+07, relative change 1.438e-06
# iteration 26, objective -8.927e+07, relative change 1.250e-06
# iteration 27, objective -8.927e+07, relative change 1.071e-06
# iteration 28, objective -8.927e+07, relative change 9.050e-07
# iteration 29, objective -8.927e+07, relative change 7.509e-07
# iteration 30, objective -8.927e+07, relative change 6.055e-07
# iteration 31, objective -8.927e+07, relative change 4.748e-07
# iteration 32, objective -8.927e+07, relative change 3.694e-07
# iteration 33, objective -8.927e+07, relative change 2.817e-07
# iteration 34, objective -8.927e+07, relative change 2.216e-07
# iteration 35, objective -8.927e+07, relative change 1.783e-07
# iteration 36, objective -8.927e+07, relative change 1.502e-07
# iteration 37, objective -8.927e+07, relative change 1.298e-07
# iteration 38, objective -8.927e+07, relative change 1.197e-07
# iteration 39, objective -8.927e+07, relative change 1.076e-07
# iteration 40, objective -8.927e+07, relative change 1.045e-07
# iteration 41, objective -8.927e+07, relative change 9.918e-08
# iteration 42, objective -8.927e+07, relative change 1.039e-07
# iteration 43, objective -8.927e+07, relative change 1.152e-07
# iteration 44, objective -8.927e+07, relative change 1.287e-07
# iteration 45, objective -8.927e+07, relative change 1.423e-07
# iteration 46, objective -8.927e+07, relative change 1.307e-07
# iteration 47, objective -8.927e+07, relative change 1.230e-07
# iteration 48, objective -8.927e+07, relative change 1.309e-07
# iteration 49, objective -8.927e+07, relative change 1.202e-07
# iteration 50, objective -8.927e+07, relative change 1.276e-07
# iteration 51, objective -8.927e+07, relative change 1.331e-07
# iteration 52, objective -8.927e+07, relative change 1.357e-07
# iteration 276, objective -8.927e+07, relative change 3.281e-10
# iteration 277, objective -8.927e+07, relative change 3.746e-11
# iteration 278, objective -8.927e+07, relative change 6.935e-10
# iteration 279, objective -8.927e+07, relative change 6.749e-10
# iteration 280, objective -8.927e+07, relative change 8.896e-10
# iteration 281, objective -8.927e+07, relative change 3.265e-10
# iteration 282, objective -8.927e+07, relative change 1.875e-10
# iteration 283, objective -8.927e+07, relative change 4.377e-10
# iteration 284, objective -8.927e+07, relative change 2.238e-10
# iteration 285, objective -8.927e+07, relative change 5.107e-10
# iteration 286, objective -8.927e+07, relative change 7.481e-10
# iteration 287, objective -8.927e+07, relative change 1.874e-10
# iteration 288, objective -8.927e+07, relative change 1.295e-09
# iteration 289, objective -8.927e+07, relative change 2.284e-09
# iteration 290, objective -8.927e+07, relative change 3.200e-09
# iteration 291, objective -8.927e+07, relative change 3.442e-09
# iteration 292, objective -8.927e+07, relative change 2.470e-09
# iteration 293, objective -8.927e+07, relative change 2.726e-09
# iteration 294, objective -8.927e+07, relative change 2.706e-09
# iteration 295, objective -8.927e+07, relative change 2.009e-09
# iteration 296, objective -8.927e+07, relative change 2.544e-09
# iteration 297, objective -8.927e+07, relative change 9.793e-10
# iteration 298, objective -8.927e+07, relative change 2.773e-10
# iteration 299, objective -8.927e+07, relative change 8.599e-10
# iteration 300, objective -8.927e+07, relative change 9.431e-10
# maximum iteration 300 reached with relative change in objective function 9.4e-10

# %%
ksfs.infer_mush((0, 1e2), (1, 1e0), # <-- mixed trend penalties
                ridge_penalty = 1e-4,
                max_iter=300, verbose=True)

plt.subplot(121)
ksfs.plot(('TCC>TTC', 'GAA>GGA'), clr=True)

plt.subplot(122)
mu_true.plot(('TCC>TTC', 'GAA>GGA'), ls='--')
ksfs.mu.plot(('TCC>TTC', 'GAA>GGA'))
# Out:
# initial objective -8.773757e+07
# iteration 1, objective -8.774e+07, relative change 2.842e-05
# iteration 2, objective -8.774e+07, relative change 9.100e-06
# iteration 3, objective -8.774e+07, relative change 3.562e-06
# iteration 4, objective -8.774e+07, relative change 1.621e-06
# iteration 5, objective -8.774e+07, relative change 8.327e-07
# iteration 6, objective -8.774e+07, relative change 5.046e-07
# iteration 7, objective -8.774e+07, relative change 4.149e-07
# iteration 8, objective -8.774e+07, relative change 3.489e-07
# iteration 9, objective -8.774e+07, relative change 3.064e-07
# iteration 10, objective -8.774e+07, relative change 2.722e-07
# iteration 11, objective -8.774e+07, relative change 2.342e-07
# iteration 12, objective -8.774e+07, relative change 1.916e-07
# iteration 13, objective -8.774e+07, relative change 1.538e-07
# iteration 14, objective -8.774e+07, relative change 1.265e-07
# iteration 15, objective -8.774e+07, relative change 1.064e-07
# iteration 16, objective -8.774e+07, relative change 9.135e-08
# iteration 17, objective -8.774e+07, relative change 8.083e-08
# iteration 18, objective -8.774e+07, relative change 6.679e-08
# iteration 19, objective -8.774e+07, relative change 5.969e-08
# iteration 20, objective -8.774e+07, relative change 5.504e-08
# iteration 21, objective -8.774e+07, relative change 4.584e-08
# iteration 22, objective -8.774e+07, relative change 4.596e-08
