# %% [markdown]
# Testing with simulations
# ==
#
# A notebook for testing `mushi`'s ability to invert data simulated under the forward model

# %%
import mushi

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib.lines import Line2D
from scipy.special import expit
import stdpopsim
# Out:
# /opt/hostedtoolcache/Python/3.9.10/x64/lib/python3.9/site-packages/traitlets/traitlets.py:3044: FutureWarning: --rc={'figure.dpi': 96} for dict-traits is deprecated in traitlets 5.0. You can pass --rc <key=value> ... multiple times to add items to a dict.
#   warn(

# %% [markdown]
# ### Time grid

# %%
change_points = np.logspace(0, np.log10(100000), 200)
t = np.concatenate((np.array([0]), change_points))

# %% [markdown]
# ### Define true demographic history

# %%
species = stdpopsim.get_species("HomSap")
model = species.get_demographic_model("Zigzag_1S14")
ddb = model.get_demography_debugger()
eta_true = mushi.eta(change_points,
                     1 / ddb.coalescence_rate_trajectory(steps=t,
                                                         lineages={0: 2},
                                                         double_step_validation=False)[0])

plt.figure(figsize=(3.5, 3.5))
eta_true.plot(c='k');

# %% [markdown]
# ### Mutation rate history $\mu(t)$
# A 96 dimensional history with a mixture of two latent signature: constant and pulse.

# %%
flat = np.ones_like(t)
pulse = expit(.1 * (t - 100)) - expit(.01 * (t - 2000))
ramp = expit(-.01 * (t - 100)) 
cols = 3
Z = np.zeros((len(t), cols))
mu0 = 1
np.random.seed(0)

Z[:, 0] = mu0 * (1 * flat + .5 * pulse)
Z[:, 1] = mu0 * (.5 * flat + .4 * ramp)
Z[:, 2] = 94 * mu0 * flat

mutation_types = ['TCC>TTC', 'GAA>GGA', None]

mu_true = mushi.mu(change_points, Z, mutation_types)

plt.figure(figsize=(4, 4))
mu_true.plot(('TCC>TTC',), alpha=0.75, lw=3, clr=False)
mu_true.plot(('GAA>GGA',), alpha=0.75, lw=3, clr=False);

# %% [markdown]
# Estimate the total mutation rate using $t=0$

# %%
mu0 = mu_true.Z[0, :].sum()
print(mu0)
# Out:
# 95.79244612935578

# %% [markdown]
# ## Simulate a $k$-SFS
# - We'll sample 200 haplotypes
# - note that this simulation will have a slightly varying total mutation rate

# %%
n = 200
ksfs = mushi.kSFS(n=n)
ksfs.simulate(eta_true, mu_true, r=0.02, seed=1)

plt.figure(figsize=(4, 3))
ksfs.plot_total(kwargs=dict(ls='', marker='.'))
plt.xscale('log')
plt.yscale('log')

plt.figure(figsize=(4, 3))
ksfs.plot(('TCC>TTC',), clr=True, kwargs=dict(alpha=0.75, ls='', marker='o'))
ksfs.plot(('GAA>GGA',), clr=True, kwargs=dict(alpha=0.75, ls='', marker='o'))
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %% [markdown]
# Number of segregating sites

# %%
ksfs.X.sum()
# Out:
# DeviceArray(9507552, dtype=int64)

# %% [markdown]
# ### TMRCA CDF

# %%
plt.figure(figsize=(3.5, 3.5))
plt.plot(change_points, ksfs.tmrca_cdf(eta_true))
plt.xlabel('$t$')
plt.ylabel('TMRCA CDF')
plt.ylim([0, 1])
plt.xscale('log')
plt.tight_layout()

# %% [markdown]
# ## Inference
#
# ### convergence parameters and time grid

# %%
convergence = dict(tol=0, max_iter=100, trend_kwargs=dict(max_iter=20))
pts = 100

# %% [markdown]
# ### Infer $\eta(t)$

# %%
trend_penalties = ((0, 1e1), (1, 1e0))

folded = False

ksfs.clear_eta()
ksfs.clear_mu()
ksfs.r = None

ksfs.infer_eta(mu0,
               *trend_penalties,
               ridge_penalty=1e-4,
               pts=pts, **convergence, verbose=True, folded=folded)

if ksfs.r is not None:
    print(f'inferred ancestral misidentification rate: {ksfs.r:.3f}')

plt.figure(figsize=(8, 4))

plt.subplot(121)
ksfs.plot_total(kwargs=dict(ls='', marker='o', ms=5, c='k', alpha=0.75),
                line_kwargs=dict(c='C0', alpha=0.75, lw=3),
                fill_kwargs=dict(color='C0', alpha=0.1),
                folded=folded)
plt.xscale('log')
plt.yscale('log')

plt.subplot(122)
eta_true.plot(c='k', lw=2, label='true')
ksfs.eta.plot(lw=3, alpha=0.75, label='inferred')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# initial objective -1.037540e+08
# iteration 1, objective -1.038e+08, relative change 5.788e-04
# iteration 2, objective -1.038e+08, relative change 1.238e-04
# iteration 3, objective -1.038e+08, relative change 5.929e-05
# iteration 4, objective -1.038e+08, relative change 3.901e-05
# iteration 5, objective -1.038e+08, relative change 3.422e-05
# iteration 6, objective -1.038e+08, relative change 3.335e-05
# iteration 7, objective -1.038e+08, relative change 3.354e-05
# iteration 8, objective -1.039e+08, relative change 3.350e-05
# iteration 9, objective -1.039e+08, relative change 3.308e-05
# iteration 10, objective -1.039e+08, relative change 3.216e-05
# iteration 11, objective -1.039e+08, relative change 3.081e-05
# iteration 12, objective -1.039e+08, relative change 2.901e-05
# iteration 13, objective -1.039e+08, relative change 2.687e-05
# iteration 14, objective -1.039e+08, relative change 2.444e-05
# iteration 15, objective -1.039e+08, relative change 2.190e-05
# iteration 16, objective -1.039e+08, relative change 1.929e-05
# iteration 17, objective -1.039e+08, relative change 1.676e-05
# iteration 18, objective -1.039e+08, relative change 1.431e-05
# iteration 19, objective -1.039e+08, relative change 1.206e-05
# iteration 20, objective -1.039e+08, relative change 9.989e-06
# iteration 21, objective -1.039e+08, relative change 8.195e-06
# iteration 22, objective -1.039e+08, relative change 6.572e-06
# iteration 23, objective -1.039e+08, relative change 5.237e-06
# iteration 24, objective -1.039e+08, relative change 4.041e-06
# iteration 25, objective -1.039e+08, relative change 3.160e-06
# iteration 26, objective -1.039e+08, relative change 2.456e-06
# iteration 27, objective -1.039e+08, relative change 1.946e-06
# iteration 28, objective -1.039e+08, relative change 1.565e-06
# iteration 29, objective -1.039e+08, relative change 1.309e-06
# iteration 30, objective -1.039e+08, relative change 1.127e-06
# iteration 31, objective -1.039e+08, relative change 1.028e-06
# iteration 32, objective -1.039e+08, relative change 9.783e-07
# iteration 33, objective -1.039e+08, relative change 9.677e-07
# iteration 34, objective -1.039e+08, relative change 9.723e-07
# iteration 35, objective -1.039e+08, relative change 9.845e-07
# iteration 36, objective -1.039e+08, relative change 9.969e-07
# iteration 37, objective -1.039e+08, relative change 1.009e-06
# iteration 38, objective -1.039e+08, relative change 1.001e-06
# iteration 39, objective -1.039e+08, relative change 9.880e-07
# iteration 40, objective -1.039e+08, relative change 9.553e-07
# iteration 41, objective -1.039e+08, relative change 9.039e-07
# iteration 42, objective -1.039e+08, relative change 8.468e-07
# iteration 43, objective -1.039e+08, relative change 7.715e-07
# iteration 44, objective -1.039e+08, relative change 6.855e-07
# iteration 45, objective -1.039e+08, relative change 6.014e-07
# iteration 46, objective -1.039e+08, relative change 5.141e-07
# iteration 47, objective -1.039e+08, relative change 4.237e-07
# iteration 48, objective -1.039e+08, relative change 3.250e-07
# iteration 49, objective -1.039e+08, relative change 2.400e-07
# iteration 50, objective -1.039e+08, relative change 1.660e-07
# iteration 51, objective -1.039e+08, relative change 1.014e-07
# iteration 52, objective -1.039e+08, relative change 4.546e-08
# iteration 53, objective -1.039e+08, relative change 7.198e-10
# iteration 54, objective -1.039e+08, relative change 4.226e-08
# iteration 55, objective -1.039e+08, relative change 7.240e-08
# iteration 56, objective -1.039e+08, relative change 9.555e-08
# iteration 57, objective -1.039e+08, relative change 9.890e-08
# iteration 58, objective -1.039e+08, relative change 9.343e-08
# iteration 59, objective -1.039e+08, relative change 8.260e-08
# iteration 60, objective -1.039e+08, relative change 7.275e-08
# iteration 61, objective -1.039e+08, relative change 5.977e-08
# iteration 62, objective -1.039e+08, relative change 4.312e-08
# iteration 63, objective -1.039e+08, relative change 2.698e-08
# iteration 64, objective -1.039e+08, relative change 3.608e-09
# iteration 65, objective -1.039e+08, relative change 1.809e-08
# iteration 66, objective -1.039e+08, relative change 1.494e-08
# iteration 67, objective -1.039e+08, relative change 3.264e-08
# iteration 68, objective -1.039e+08, relative change 2.569e-08
# iteration 69, objective -1.039e+08, relative change 3.329e-08
# iteration 70, objective -1.039e+08, relative change 4.797e-08
# iteration 71, objective -1.039e+08, relative change 5.305e-08
# iteration 72, objective -1.039e+08, relative change 5.361e-08
# iteration 73, objective -1.039e+08, relative change 6.511e-08
# iteration 74, objective -1.039e+08, relative change 7.415e-08
# iteration 75, objective -1.039e+08, relative change 8.118e-08
# iteration 76, objective -1.039e+08, relative change 6.833e-08
# iteration 77, objective -1.039e+08, relative change 6.449e-08
# iteration 78, objective -1.039e+08, relative change 6.458e-08
# iteration 79, objective -1.039e+08, relative change 6.378e-08
# iteration 80, objective -1.039e+08, relative change 5.695e-08
# iteration 81, objective -1.039e+08, relative change 5.744e-08
# iteration 82, objective -1.039e+08, relative change 6.083e-08
# iteration 83, objective -1.039e+08, relative change 6.425e-08
# iteration 84, objective -1.039e+08, relative change 6.020e-08
# iteration 85, objective -1.039e+08, relative change 6.226e-08
# iteration 86, objective -1.039e+08, relative change 6.372e-08
# iteration 87, objective -1.039e+08, relative change 4.632e-08
# iteration 88, objective -1.039e+08, relative change 3.991e-08
# iteration 89, objective -1.039e+08, relative change 4.440e-08
# iteration 90, objective -1.039e+08, relative change 1.819e-08
# iteration 91, objective -1.039e+08, relative change 1.978e-08
# iteration 92, objective -1.039e+08, relative change 2.106e-08
# iteration 93, objective -1.039e+08, relative change 4.150e-09
# iteration 94, objective -1.039e+08, relative change 4.459e-09
# iteration 95, objective -1.039e+08, relative change 7.076e-09
# iteration 96, objective -1.039e+08, relative change 1.485e-08
# iteration 97, objective -1.039e+08, relative change 1.989e-08
# iteration 98, objective -1.039e+08, relative change 2.770e-08
# iteration 99, objective -1.039e+08, relative change 3.461e-08
# iteration 100, objective -1.039e+08, relative change 4.006e-08
# maximum iteration 100 reached with relative change in objective function 4e-08
# inferred ancestral misidentification rate: 0.020

# %% [markdown]
# ### Infer $\boldsymbol\mu(t)$

# %%
ksfs.clear_mu()

trend_penalties = ((0, 2e2), (3, 1e-1))

ksfs.infer_mush(*trend_penalties, ridge_penalty=1e-4,
                **convergence, verbose=True)

plt.figure(figsize=(8, 4))

plt.subplot(121)
ksfs.plot(('TCC>TTC',), clr=True, kwargs=dict(alpha=0.75, ls='', marker='.', ms=10, mfc='none', c='C0'),
          line_kwargs=dict(alpha=0.75, lw=2, c='C0'))
ksfs.plot(('GAA>GGA',), clr=True, kwargs=dict(alpha=0.75, ls='', marker='.', ms=10, mfc='none', c='C1'),
          line_kwargs=dict(alpha=0.75, lw=2, c='C1'))

plt.subplot(122)
mu_true.plot(('TCC>TTC',), alpha=0.75, lw=2, c='C0')
ksfs.mu.plot(('TCC>TTC',), alpha=0.75, lw=3, ls='--', c='C0')
mu_true.plot(('GAA>GGA',), alpha=0.75, lw=2, c='C1')
ksfs.mu.plot(('GAA>GGA',), alpha=0.75, lw=3, ls='--', c='C1')
plt.tight_layout()
plt.show()
# Out:
# initial objective -1.028993e+08
# iteration 1, objective -1.029e+08, relative change 6.655e-06
# iteration 2, objective -1.029e+08, relative change 1.168e-06
# iteration 3, objective -1.029e+08, relative change 7.708e-07
# iteration 4, objective -1.029e+08, relative change 5.359e-07
# iteration 5, objective -1.029e+08, relative change 2.129e-07
# iteration 6, objective -1.029e+08, relative change 7.014e-08
# iteration 7, objective -1.029e+08, relative change 3.448e-08
# iteration 8, objective -1.029e+08, relative change 1.430e-08
# iteration 9, objective -1.029e+08, relative change 2.101e-08
# iteration 10, objective -1.029e+08, relative change 8.590e-09
# iteration 11, objective -1.029e+08, relative change 6.082e-09
# iteration 12, objective -1.029e+08, relative change 2.523e-08
# iteration 13, objective -1.029e+08, relative change 2.412e-08
# iteration 14, objective -1.029e+08, relative change 3.103e-08
# iteration 15, objective -1.029e+08, relative change 4.160e-08
# iteration 16, objective -1.029e+08, relative change 5.257e-08
# iteration 17, objective -1.029e+08, relative change 1.041e-07
# iteration 18, objective -1.029e+08, relative change 1.283e-07
# iteration 19, objective -1.029e+08, relative change 4.307e-08
# iteration 20, objective -1.029e+08, relative change 5.264e-08
# iteration 21, objective -1.029e+08, relative change 2.325e-08
# iteration 22, objective -1.029e+08, relative change 3.090e-08
# iteration 23, objective -1.029e+08, relative change 3.853e-08
# iteration 24, objective -1.029e+08, relative change 2.641e-08
# iteration 25, objective -1.029e+08, relative change 1.623e-08
# iteration 26, objective -1.029e+08, relative change 2.817e-08
# iteration 27, objective -1.029e+08, relative change 9.047e-09
# iteration 28, objective -1.029e+08, relative change 7.793e-10
# iteration 29, objective -1.029e+08, relative change 4.279e-09
# iteration 30, objective -1.029e+08, relative change 5.046e-10
# iteration 31, objective -1.029e+08, relative change 4.657e-09
# iteration 32, objective -1.029e+08, relative change 5.425e-09
# iteration 33, objective -1.029e+08, relative change 4.372e-09
# iteration 34, objective -1.029e+08, relative change 5.569e-09
# iteration 35, objective -1.029e+08, relative change 5.425e-09
# iteration 36, objective -1.029e+08, relative change 9.038e-09
# iteration 37, objective -1.029e+08, relative change 3.799e-09
# iteration 38, objective -1.029e+08, relative change 2.783e-09
# iteration 39, objective -1.029e+08, relative change 1.444e-09
# iteration 40, objective -1.029e+08, relative change 7.486e-10
# iteration 41, objective -1.029e+08, relative change 4.669e-09
# iteration 42, objective -1.029e+08, relative change 9.865e-10
# iteration 43, objective -1.029e+08, relative change 1.054e-09
# iteration 44, objective -1.029e+08, relative change 5.236e-10
# iteration 45, objective -1.029e+08, relative change 5.142e-10
# iteration 46, objective -1.029e+08, relative change 8.795e-10
# iteration 47, objective -1.029e+08, relative change 4.504e-10
# iteration 48, objective -1.029e+08, relative change 5.445e-11
# iteration 49, objective -1.029e+08, relative change 2.118e-10
# iteration 50, objective -1.029e+08, relative change 1.210e-10
# iteration 51, objective -1.029e+08, relative change 1.288e-10
# iteration 52, objective -1.029e+08, relative change 1.938e-09
# iteration 53, objective -1.029e+08, relative change 2.308e-09
# iteration 54, objective -1.029e+08, relative change 2.426e-09
# iteration 55, objective -1.029e+08, relative change 2.893e-09
# iteration 56, objective -1.029e+08, relative change 5.586e-09
# iteration 57, objective -1.029e+08, relative change 1.505e-09
# iteration 58, objective -1.029e+08, relative change 2.926e-10
# iteration 59, objective -1.029e+08, relative change 7.084e-10
# iteration 60, objective -1.029e+08, relative change 1.428e-09
# iteration 61, objective -1.029e+08, relative change 1.877e-09
# iteration 62, objective -1.029e+08, relative change 1.840e-09
# iteration 63, objective -1.029e+08, relative change 1.367e-09
# iteration 64, objective -1.029e+08, relative change 6.825e-10
# iteration 65, objective -1.029e+08, relative change 1.744e-11
# iteration 66, objective -1.029e+08, relative change 4.764e-10
# iteration 67, objective -1.029e+08, relative change 7.466e-10
# iteration 68, objective -1.029e+08, relative change 8.163e-10
# iteration 69, objective -1.029e+08, relative change 7.481e-10
# iteration 70, objective -1.029e+08, relative change 6.128e-10
# iteration 71, objective -1.029e+08, relative change 4.909e-10
# iteration 72, objective -1.029e+08, relative change 5.039e-10
# iteration 73, objective -1.029e+08, relative change 4.561e-10
# iteration 74, objective -1.029e+08, relative change 4.536e-10
# iteration 75, objective -1.029e+08, relative change 4.855e-10
# iteration 76, objective -1.029e+08, relative change 5.360e-10
# iteration 77, objective -1.029e+08, relative change 1.668e-09
# iteration 78, objective -1.029e+08, relative change 1.551e-09
# iteration 79, objective -1.029e+08, relative change 7.756e-10
# iteration 80, objective -1.029e+08, relative change 1.634e-09
# iteration 81, objective -1.029e+08, relative change 2.029e-09
# iteration 82, objective -1.029e+08, relative change 1.856e-09
# iteration 83, objective -1.029e+08, relative change 1.694e-09
# iteration 84, objective -1.029e+08, relative change 1.332e-09
# iteration 85, objective -1.029e+08, relative change 8.983e-10
# iteration 86, objective -1.029e+08, relative change 5.002e-10
# iteration 87, objective -1.029e+08, relative change 1.964e-10
# iteration 88, objective -1.029e+08, relative change 2.782e-12
# iteration 89, objective -1.029e+08, relative change 9.556e-11
# iteration 90, objective -1.029e+08, relative change 1.289e-10
# iteration 91, objective -1.029e+08, relative change 1.286e-10
# iteration 92, objective -1.029e+08, relative change 1.200e-10
# iteration 93, objective -1.029e+08, relative change 1.200e-10
# iteration 94, objective -1.029e+08, relative change 1.371e-10
# iteration 95, objective -1.029e+08, relative change 1.730e-10
# iteration 96, objective -1.029e+08, relative change 2.248e-10
# iteration 97, objective -1.029e+08, relative change 2.884e-10
# iteration 98, objective -1.029e+08, relative change 3.574e-10
# iteration 99, objective -1.029e+08, relative change 4.257e-10
# iteration 100, objective -1.029e+08, relative change 4.899e-10
# maximum iteration 100 reached with relative change in objective function 4.9e-10
