# %% [markdown]
# Investigating the $C$ matrix
# ==

# %%
# %matplotlib notebook
from mushi import SFS
import numpy as np
from matplotlib import pyplot as plt
from numpy.linalg import cond, svd

# %% [markdown]
# ### The condition number $\kappa(A_n)$ for several values of $n$
# Things go to 💩 for $n$ larger than a couple hundred or so. This is a problem

# %%
ns = np.logspace(1, 2.6, 100, dtype=np.int)
condition_numbers = [cond(SFS.C(n)) for n in ns]
plt.plot(ns, condition_numbers)
plt.xlabel('$n$')
plt.ylabel('$\kappa(C)$')
plt.xscale('log')
plt.yscale('log')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Singular value spectra

# %%
plt.figure()
for n in np.logspace(1, 2.6, 20, dtype=int):
    plt.plot(np.arange(1, n), svd(SFS.C(n))[1], label='$n = {}$'.format(n))
plt.ylabel('singular value')    
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Just a colormap of the matrix

# %%
n = 200
plt.matshow(SFS.C(n))
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="480">
